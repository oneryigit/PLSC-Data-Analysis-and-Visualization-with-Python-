# %% [markdown]
# # **PLSC - Political Science Poli.Analysis & Data w/ Python**
#
# ## **Summer 2023**
#
# ### Oner Yigit
# ### Political Science
# ### Binghamton University
# ### [Email](oyigit1@binghamton.edu )

# %% [markdown]
# ## **Markdown Essentials**
#
# ### **How to use Python notebook for non-code related tasks such as note taking, explanations etc.**
#
#
# Headings
# Use the number sign (#) followed by a blank space for notebook titles and section headings:
#
# # for titles
# ## for major headings
# ### for subheadings
# #### for 4th level subheadings
#
# Emphasis
# >  Use the following code to emphasize text:
#
# >  Bold text: __string__ or **string**
#
# >  Italic text: _string_ or *string*
#
# ### For mathematical symbols
# This is the binomial log-likelihood function.
#
# $$
# \ln \mathcal{L}(\pi \mid y)=\sum_{i=1}^n\left[y_i \ln \left(F\left(x_i \widehat{\beta}\right)\right)+\left(1-y_i\right) \ln \left(1-F\left(x_i \widehat{\beta}\right)\right)\right]
# $$
#
# Monospace font
#
# `data science`, `python`, `pandas`
#
# You can create bullets using hyphen (-).
# For sub bullet, use tab and then hypen.
#
# - item 1
#   - subitem 1
#     - itemx
# - item 2
#   - subitem 2
# - item 3
#
# or you can use asterisk (*)
#
# * item 1
# * item 2
# * item 3
#
#
# Numbered lists.
# It does not matter if you use (1) for all.
#
# 1. a
# 1. b
# 1. c
# 1. d
#
# same logic with bullets applies here as well.
# 1. item1
#   1. Subitem1
#   1. subitem2
# 1. item2
#   1. subitem1
#   1. subitem2
#
# [Binghamton Univ](https://www.binghamton.edu/)
#
# __[Binghamton University](https://www.binghamton.edu/)__

# %%
from IPython import display
display.Image("https://3.bp.blogspot.com/-apoBeWFycKQ/XhKB8fEprwI/AAAAAAAACM4/Sl76yzNSNYwlShIBrheDAum8L9qRtWNdgCLcBGAsYHQ/s1600/colab.png")

# %%
from IPython import display
display.YouTubeVideo(id="umgSZWpyl6Q")

#https://www.youtube.com/watch?v=umgSZWpyl6Q&ab_channel=BinghamtonUniversity

# %% [markdown]
# Now, we are ready to code

# %% [markdown]
# # **Module 1**

# %%
#this is a cell where we run codes.

# we use (#) when we want to annotate our codes.

2+3
# Out:
# 5

# %%
print('Hello world!')

#print is a built-in function.
#we can use 'Hello world!' or "Hello world!" they are the same.
# Out:
# Hello world!

# %%
"hello world!"
# Out:
# 'hello world!'

# %%
"double quotes"
# Out:
# 'double quotes'

# %%
'single quotes'
# Out:
# 'single quotes'

# %%
"wrap lot's of other quotes"
# Out:
# " wrap lot's of other quotes"

# %%
1+1
# Out:
# 2

# %%
3*2
# Out:
# 6

# %%
2**3
# Out:
# 8

# %%
5/10
# Out:
# 0.5

# %%
5%2 #remaining
# Out:
# 1

# %%
(2 + 3) * (5 + 5)
# Out:
# 50

# %%
#str: string(text, characters)
type("hello world")
# Out:
# str

# %%
#int: integers(Whole numbers)
type(5)
# Out:
# int

# %%
type(3.6)
# Out:
# float

# %%
int(3.6) # rounds the float to the smaller integer
# Out:
# 3

# %%
#float: float(Numbers with a decimal point)
type(5.2)
# Out:
# float

# %%
float(4) # integer 4 becomes float 4.0
# Out:
# 4.0

# %%
#bool: boolean(Logical value True or False)
type(4+2==9-3)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
4+2==9-3
# Out:
# True

# %%
2==1
# Out:
# False

# %%
1 > 2
# Out:
# False

# %%
1 <= 4
# Out:
# True

# %%
(1 > 2) and (2 < 3)
# Out:
# False

# %%
(1 == 2) or (2 == 3) or (4 == 4)
# Out:
# True

# %%
(True) and (False)
# Out:
# False

# %%
(True) or (False)
# Out:
# True

# %%
(not True) and (not False) or (False)
# Out:
# False

# %%
# Can not start with number or special characters
name_of_var = 2

# %%
#We assign values to variables with =
num1 = 1.5
num2 = 6.3

# %%
# Add two numbers
sum = num1 + num2
# Display the sum
print(sum)
7.8
# Out:
# 7.8
# 7.8

# %%
pi = 3.14159
radius = 5
print(pi)
print(radius)
# Out:
# 3.14159
# 5

# %%
area = pi * (radius ** 2)
print(area)
# Out:
# 78.53975

# %%
circumference = 2 * pi * radius
print(circumference)
# Out:
# 31.4159

# %%
num = 18
name = 'Oner'

# %%
print('My number is: {x}, and my name is: {y}'.format(x=num,y=name))
# Out:
# My number is: 18, and my name is: Oner

# %%
print('My number is: {}, and my name is: {}'.format(num,name))
# Out:
# My number is: 18, and my name is: Oner

# %%
x=10
print(x)
# Out:
# 10

# %%
x=x+1
print(x)
# Out:
# 11

# %%
# dictionary
d = {'key1':'item1','key2':'item2'}

# %%
d
# Out:
# {'key1': 'item1', 'key2': 'item2'}

# %%
d['key1']
# Out:
# 'item1'

# %%
# Creating a dictionary
student = {
    'name': 'John Smith',
    'age': 20,
    'major': 'Computer Science',
    'university': 'ABC University'}

# %%
student['major']
# Out:
# 'Computer Science'

# %%
# Creating a list
fruits = ['apple', 'banana', 'orange', 'grape']

# %%
['hi',1,[1,2]]

#list can have list within.
# it can include integers, strings, etc.
# Out:
# ['hi', 1, [1, 2]]

# %%
my_list = ['a','b','c']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[1:]
# Out:
# ['b', 'c', 'd']

# %%
my_list[0] = 'NEW'

# %%
my_list
# Out:
# ['NEW', 'b', 'c', 'd']

# %%
nest = [1,2,3,[4,5,['target']]]

# %%
nest[3]
# Out:
# [4, 5, ['target']]

# %%
nest[3][2]
# Out:
# ['target']

# %%
# Creating a data with dictionary and list together
student = {
    'name': ['John', 'Smith'],
    'age': [20, 21],
    'major': ['Computer Science', "Political Science"],
    'university': ['ABC University', "Binghamton University"]}

# %%
#turn it into a excel-like format

student = {
    'name': ['John', 'Smith'],
    'age': [20, 21],
    'major': ['Computer Science', 'Political Science'],
    'university': ['ABC University', 'Binghamton University']}

import pandas as pd
df = pd.DataFrame(student)
df
# Out:
#     name  age              major             university
# 0   John   20   Computer Science         ABC University
# 1  Smith   21  Political Science  Binghamton University

# %%
student['major']
# Out:
# ['Computer Science', 'Political Science']

# %%
# how can we reach out political science by slicing.
student['major'][1]
# Out:
# 'Political Science'

# %%
student['name'][1]
# Out:
# 'Smith'

# %%
#We can ask if the second student's name is Smith.

student['name'][1]=='Smith'
# Out:
# True

# %%
# Creating a tuple
student = ('John Smith', 20, 'Computer Science', 'ABC University')

# %%
t = (1,2,3)

# %%
t[0]
# Out:
# 1

# %%
t[0] = 'NEW'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-93bfe9be1549> in <cell line: 1>()
# ----> 1 t[0] = 'NEW'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Creating a set
fruits = {'apple', 'banana', 'orange', 'grape'}

# %%
{1, 2, 3}
# Out:
# {1, 2, 3}

# %%
{1,2,3,1,2,1,2,3,3,3,3,2,2,2,1,1,2}
# Out:
# {1, 2, 3}
